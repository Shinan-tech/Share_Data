# %%
from bs4 import BeautifulSoup as bs
import requests
import re
import json

# %%
''' Will ask if it is possible to select the time period automaticlly
r = requests.get("https://www.finanzen.net/historische-kurse/covestro")
soup = bs(r.content)
contents = soup.prettify()
print(contents)
table_quotes = soup.find("div", {"class":"col-sm-8"})
print(table_quotes.prettify())
'''
# Out:
# <!DOCTYPE html>
# <html lang="de" prefix="og: http://ogp.me/ns#">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link crossorigin="" href="//c.finanzen.net" rel="preconnect"/>
#   <link crossorigin="" href="//images.finanzen.net" rel="preconnect"/>
#   <link crossorigin="" href="//styles.finanzen.net" rel="preconnect"/>
#   <link crossorigin="" href="//scripts.finanzen.net" rel="preconnect"/>
#   <link crossorigin="" href="//mdsngpush.finanzen.net" rel="preconnect"/>
#   <link as="font" crossorigin="" href="https://styles.finanzen.net/fonts/glyphicons-halflings-regular.woff2" rel="preload" type="font/woff2"/>
#   <link crossorigin="" href="//www.asadcdn.com" rel="preconnect"/>
#   <link href="//cdn1.smartadserver.com" rel="dns-prefetch"/>
#   <link href="//ww251.smartadserver.com" rel="dns-prefetch"/>
#   <link href="//adtechnology.mediaimpact.de" rel="dns-prefetch"/>
# ...

# %%
from alpha_vantage.timeseries import TimeSeries

# %%
with open("alpha_vantage_access.json", "r") as infile:
    my_access_key = json.loads(infile.read())
ts = TimeSeries(key="my_access_key", output_format="pandas")
data, meta_data = ts.get_intraday(symbol="MSFT", interval="1min", outputsize="full")

print(data.head(2))
# Out:
#                      1. open  2. high  3. low  4. close  5. volume
# date
# 2020-10-14 20:00:00    220.3    220.3   220.3     220.3     3332.0
# 2020-10-14 19:59:00    220.3    220.3   220.3     220.3      274.0
